# %%
import pandas as pd

# %%
df = pd.read_excel('2023-1-sprint1-responses.xlsx')

# %%
df.head(2)
# Out:
#                 Timestamp            Email Address
# 0 2023-05-16 17:36:10.467       01tato02@gmail.com  \
# 1 2023-05-16 17:42:24.150  guoliveira255@gmail.com
#
#                       Selecione o seu Nome
# 0         TALES IVALQUE TAVEIRA DE FREITAS  \
# 1  Gustavo Eliziario Stevenson de Oliveira
#
#    Qual nível de PRODUTIVIDADE cada membro teve na sprint anterior? (LEIA A RUBRICA, POIS ISSO NÃO É SIMPLESMENTE UMA NOTA)\n\nNa linha com o seu nome, faça a sua autoavaliação [ALBERTO MARTINS PEREIRA CARRERA]
# 0                                                NaN                                                                                                                                                                \
# 1                                                NaN
#
#    Qual nível de PRODUTIVIDADE cada membro teve na sprint anterior? (LEIA A RUBRICA, POIS ISSO NÃO É SIMPLESMENTE UMA NOTA)\n\nNa linha com o seu nome, faça a sua autoavaliação [DOUGLAS PABLO]
# 0                                                NaN                                                                                                                                              \
# 1                                                NaN
#
#    Qual nível de PRODUTIVIDADE cada membro teve na sprint anterior? (LEIA A RUBRICA, POIS ISSO NÃO É SIMPLESMENTE UMA NOTA)\n\nNa linha com o seu nome, faça a sua autoavaliação [PEDRO GOMES DE SÁ DRUMOND]
# 0                                                NaN                                                                                                                                                          \
# 1                                                NaN
#
#    Qual nível de PRODUTIVIDADE cada membro teve na sprint anterior? (LEIA A RUBRICA, POIS ISSO NÃO É SIMPLESMENTE UMA NOTA)\n\nNa linha com o seu nome, faça a sua autoavaliação [PEDRO IVO AMARAL LIMA]
# 0                                                NaN                                                                                                                                                      \
# 1                                                NaN
#
#    Qual nível de PROATIVIDADE cada membro teve na sprint anterior? (LEIA A RUBRICA, POIS ISSO NÃO É SIMPLESMENTE UMA NOTA)\n\nNa linha com o seu nome, faça a sua autoavaliação [ALBERTO MARTINS PEREIRA CARRERA]
# 0                                                NaN                                                                                                                                                               \
# 1                                                NaN
#
#    Qual nível de PROATIVIDADE cada membro teve na sprint anterior? (LEIA A RUBRICA, POIS ISSO NÃO É SIMPLESMENTE UMA NOTA)\n\nNa linha com o seu nome, faça a sua autoavaliação [DOUGLAS PABLO]
# 0                                                NaN                                                                                                                                             \
# 1                                                NaN
#
#    Qual nível de PROATIVIDADE cada membro teve na sprint anterior? (LEIA A RUBRICA, POIS ISSO NÃO É SIMPLESMENTE UMA NOTA)\n\nNa linha com o seu nome, faça a sua autoavaliação [PEDRO GOMES DE SÁ DRUMOND]
# 0                                                NaN                                                                                                                                                         \
# 1                                                NaN
#
#    ...
# 0  ...  \
# 1  ...
#
#    Qual nível de PRODUTIVIDADE cada membro teve na sprint anterior? (LEIA A RUBRICA, POIS ISSO NÃO É SIMPLESMENTE UMA NOTA)\n\nNa linha com o seu nome, faça a sua autoavaliação [RAFAEL PASCARELLI NICCHERI]
# 0                                                3.0                                                                                                                                                           \
# 1                                                NaN
#
#    Qual nível de PRODUTIVIDADE cada membro teve na sprint anterior? (LEIA A RUBRICA, POIS ISSO NÃO É SIMPLESMENTE UMA NOTA)\n\nNa linha com o seu nome, faça a sua autoavaliação [TALES IVALQUE TAVEIRA DE FREITAS]
# 0                                                3.0                                                                                                                                                                 \
# 1                                                NaN
#
#    Qual nível de PROATIVIDADE cada membro teve na sprint anterior? (LEIA A RUBRICA, POIS ISSO NÃO É SIMPLESMENTE UMA NOTA)\n\nNa linha com o seu nome, faça a sua autoavaliação [LUCAS HIX]
# 0                                                3.0                                                                                                                                         \
# 1                                                NaN
#
#    Qual nível de PROATIVIDADE cada membro teve na sprint anterior? (LEIA A RUBRICA, POIS ISSO NÃO É SIMPLESMENTE UMA NOTA)\n\nNa linha com o seu nome, faça a sua autoavaliação [PEDRO BALBO PORTELLA]
# 0                                                3.0                                                                                                                                                    \
# 1                                                NaN
#
#    Qual nível de PROATIVIDADE cada membro teve na sprint anterior? (LEIA A RUBRICA, POIS ISSO NÃO É SIMPLESMENTE UMA NOTA)\n\nNa linha com o seu nome, faça a sua autoavaliação [RAFAEL PASCARELLI NICCHERI]
# 0                                                3.0                                                                                                                                                          \
# 1                                                NaN
#
#    Qual nível de PROATIVIDADE cada membro teve na sprint anterior? (LEIA A RUBRICA, POIS ISSO NÃO É SIMPLESMENTE UMA NOTA)\n\nNa linha com o seu nome, faça a sua autoavaliação [TALES IVALQUE TAVEIRA DE FREITAS]
# 0                                                3.0                                                                                                                                                                \
# 1                                                NaN
#
#    Qual nível de TRANSPARÊNCIA cada membro teve na sprint anterior? (LEIA A RUBRICA, POIS ISSO NÃO É SIMPLESMENTE UMA NOTA)\n\nNa linha com o seu nome, faça a sua autoavaliação [LUCAS HIX]
# 0                                                3.0                                                                                                                                          \
# 1                                                NaN
#
#    Qual nível de TRANSPARÊNCIA cada membro teve na sprint anterior? (LEIA A RUBRICA, POIS ISSO NÃO É SIMPLESMENTE UMA NOTA)\n\nNa linha com o seu nome, faça a sua autoavaliação [PEDRO BALBO PORTELLA]
# 0                                                3.0                                                                                                                                                     \
# 1                                                NaN
#
#    Qual nível de TRANSPARÊNCIA cada membro teve na sprint anterior? (LEIA A RUBRICA, POIS ISSO NÃO É SIMPLESMENTE UMA NOTA)\n\nNa linha com o seu nome, faça a sua autoavaliação [RAFAEL PASCARELLI NICCHERI]
# 0                                                3.0                                                                                                                                                           \
# 1                                                NaN
#
#    Qual nível de TRANSPARÊNCIA cada membro teve na sprint anterior? (LEIA A RUBRICA, POIS ISSO NÃO É SIMPLESMENTE UMA NOTA)\n\nNa linha com o seu nome, faça a sua autoavaliação [TALES IVALQUE TAVEIRA DE FREITAS]
# 0                                                3.0
# 1                                                NaN
#
# [2 rows x 105 columns]

# %%
df.set_index('Selecione o seu Nome', inplace=True)
df.drop(['Timestamp'], axis=1, inplace=True)
df.drop(['Email Address'], axis=1, inplace=True)

# %%
columns = df.columns

# %%
df.head()
# Out:
#                                          Qual nível de PRODUTIVIDADE cada membro teve na sprint anterior? (LEIA A RUBRICA, POIS ISSO NÃO É SIMPLESMENTE UMA NOTA)\n\nNa linha com o seu nome, faça a sua autoavaliação [ALBERTO MARTINS PEREIRA CARRERA]
# Selecione o seu Nome
# TALES IVALQUE TAVEIRA DE FREITAS                                                       NaN                                                                                                                                                                \
# Gustavo Eliziario Stevenson de Oliveira                                                NaN
# LUCA MIZRAHI                                                                           NaN
# RODRIGO PAOLIELLO DE MEDEIROS                                                          NaN
# LUCAS HIX                                                                              NaN
#
#                                          Qual nível de PRODUTIVIDADE cada membro teve na sprint anterior? (LEIA A RUBRICA, POIS ISSO NÃO É SIMPLESMENTE UMA NOTA)\n\nNa linha com o seu nome, faça a sua autoavaliação [DOUGLAS PABLO]
# Selecione o seu Nome
# TALES IVALQUE TAVEIRA DE FREITAS                                                       NaN                                                                                                                                              \
# Gustavo Eliziario Stevenson de Oliveira                                                NaN
# LUCA MIZRAHI                                                                           NaN
# RODRIGO PAOLIELLO DE MEDEIROS                                                          NaN
# LUCAS HIX                                                                              NaN
#
#                                          Qual nível de PRODUTIVIDADE cada membro teve na sprint anterior? (LEIA A RUBRICA, POIS ISSO NÃO É SIMPLESMENTE UMA NOTA)\n\nNa linha com o seu nome, faça a sua autoavaliação [PEDRO GOMES DE SÁ DRUMOND]
# Selecione o seu Nome
# TALES IVALQUE TAVEIRA DE FREITAS                                                       NaN                                                                                                                                                          \
# Gustavo Eliziario Stevenson de Oliveira                                                NaN
# LUCA MIZRAHI                                                                           NaN
# RODRIGO PAOLIELLO DE MEDEIROS                                                          NaN
# LUCAS HIX                                                                              NaN
#
#                                          Qual nível de PRODUTIVIDADE cada membro teve na sprint anterior? (LEIA A RUBRICA, POIS ISSO NÃO É SIMPLESMENTE UMA NOTA)\n\nNa linha com o seu nome, faça a sua autoavaliação [PEDRO IVO AMARAL LIMA]
# Selecione o seu Nome
# TALES IVALQUE TAVEIRA DE FREITAS                                                       NaN                                                                                                                                                      \
# Gustavo Eliziario Stevenson de Oliveira                                                NaN
# LUCA MIZRAHI                                                                           NaN
# RODRIGO PAOLIELLO DE MEDEIROS                                                          NaN
# LUCAS HIX                                                                              NaN
#
#                                          Qual nível de PROATIVIDADE cada membro teve na sprint anterior? (LEIA A RUBRICA, POIS ISSO NÃO É SIMPLESMENTE UMA NOTA)\n\nNa linha com o seu nome, faça a sua autoavaliação [ALBERTO MARTINS PEREIRA CARRERA]
# Selecione o seu Nome
# TALES IVALQUE TAVEIRA DE FREITAS                                                       NaN                                                                                                                                                               \
# Gustavo Eliziario Stevenson de Oliveira                                                NaN
# LUCA MIZRAHI                                                                           NaN
# RODRIGO PAOLIELLO DE MEDEIROS                                                          NaN
# LUCAS HIX                                                                              NaN
#
#                                          Qual nível de PROATIVIDADE cada membro teve na sprint anterior? (LEIA A RUBRICA, POIS ISSO NÃO É SIMPLESMENTE UMA NOTA)\n\nNa linha com o seu nome, faça a sua autoavaliação [DOUGLAS PABLO]
# Selecione o seu Nome
# TALES IVALQUE TAVEIRA DE FREITAS                                                       NaN                                                                                                                                             \
# Gustavo Eliziario Stevenson de Oliveira                                                NaN
# LUCA MIZRAHI                                                                           NaN
# RODRIGO PAOLIELLO DE MEDEIROS                                                          NaN
# LUCAS HIX                                                                              NaN
#
#                                          Qual nível de PROATIVIDADE cada membro teve na sprint anterior? (LEIA A RUBRICA, POIS ISSO NÃO É SIMPLESMENTE UMA NOTA)\n\nNa linha com o seu nome, faça a sua autoavaliação [PEDRO GOMES DE SÁ DRUMOND]
# Selecione o seu Nome
# TALES IVALQUE TAVEIRA DE FREITAS                                                       NaN                                                                                                                                                         \
# Gustavo Eliziario Stevenson de Oliveira                                                NaN
# LUCA MIZRAHI                                                                           NaN
# RODRIGO PAOLIELLO DE MEDEIROS                                                          NaN
# LUCAS HIX                                                                              NaN
#
#                                          Qual nível de PROATIVIDADE cada membro teve na sprint anterior? (LEIA A RUBRICA, POIS ISSO NÃO É SIMPLESMENTE UMA NOTA)\n\nNa linha com o seu nome, faça a sua autoavaliação [PEDRO IVO AMARAL LIMA]
# Selecione o seu Nome
# TALES IVALQUE TAVEIRA DE FREITAS                                                       NaN                                                                                                                                                     \
# Gustavo Eliziario Stevenson de Oliveira                                                NaN
# LUCA MIZRAHI                                                                           NaN
# RODRIGO PAOLIELLO DE MEDEIROS                                                          NaN
# LUCAS HIX                                                                              NaN
#
#                                          Qual nível de TRANSPARÊNCIA cada membro teve na sprint anterior? (LEIA A RUBRICA, POIS ISSO NÃO É SIMPLESMENTE UMA NOTA)\n\nNa linha com o seu nome, faça a sua autoavaliação [ALBERTO MARTINS PEREIRA CARRERA]
# Selecione o seu Nome
# TALES IVALQUE TAVEIRA DE FREITAS                                                       NaN                                                                                                                                                                \
# Gustavo Eliziario Stevenson de Oliveira                                                NaN
# LUCA MIZRAHI                                                                           NaN
# RODRIGO PAOLIELLO DE MEDEIROS                                                          NaN
# LUCAS HIX                                                                              NaN
#
#                                          Qual nível de TRANSPARÊNCIA cada membro teve na sprint anterior? (LEIA A RUBRICA, POIS ISSO NÃO É SIMPLESMENTE UMA NOTA)\n\nNa linha com o seu nome, faça a sua autoavaliação [DOUGLAS PABLO]
# Selecione o seu Nome
# TALES IVALQUE TAVEIRA DE FREITAS                                                       NaN                                                                                                                                              \
# Gustavo Eliziario Stevenson de Oliveira                                                NaN
# LUCA MIZRAHI                                                                           NaN
# RODRIGO PAOLIELLO DE MEDEIROS                                                          NaN
# LUCAS HIX                                                                              NaN
#
#                                          ...
# Selecione o seu Nome                     ...
# TALES IVALQUE TAVEIRA DE FREITAS         ...  \
# Gustavo Eliziario Stevenson de Oliveira  ...
# LUCA MIZRAHI                             ...
# RODRIGO PAOLIELLO DE MEDEIROS            ...
# LUCAS HIX                                ...
#
#                                          Qual nível de PRODUTIVIDADE cada membro teve na sprint anterior? (LEIA A RUBRICA, POIS ISSO NÃO É SIMPLESMENTE UMA NOTA)\n\nNa linha com o seu nome, faça a sua autoavaliação [RAFAEL PASCARELLI NICCHERI]
# Selecione o seu Nome
# TALES IVALQUE TAVEIRA DE FREITAS                                                       3.0                                                                                                                                                           \
# Gustavo Eliziario Stevenson de Oliveira                                                NaN
# LUCA MIZRAHI                                                                           NaN
# RODRIGO PAOLIELLO DE MEDEIROS                                                          NaN
# LUCAS HIX                                                                              3.0
#
#                                          Qual nível de PRODUTIVIDADE cada membro teve na sprint anterior? (LEIA A RUBRICA, POIS ISSO NÃO É SIMPLESMENTE UMA NOTA)\n\nNa linha com o seu nome, faça a sua autoavaliação [TALES IVALQUE TAVEIRA DE FREITAS]
# Selecione o seu Nome
# TALES IVALQUE TAVEIRA DE FREITAS                                                       3.0                                                                                                                                                                 \
# Gustavo Eliziario Stevenson de Oliveira                                                NaN
# LUCA MIZRAHI                                                                           NaN
# RODRIGO PAOLIELLO DE MEDEIROS                                                          NaN
# LUCAS HIX                                                                              3.0
#
#                                          Qual nível de PROATIVIDADE cada membro teve na sprint anterior? (LEIA A RUBRICA, POIS ISSO NÃO É SIMPLESMENTE UMA NOTA)\n\nNa linha com o seu nome, faça a sua autoavaliação [LUCAS HIX]
# Selecione o seu Nome
# TALES IVALQUE TAVEIRA DE FREITAS                                                       3.0                                                                                                                                         \
# Gustavo Eliziario Stevenson de Oliveira                                                NaN
# LUCA MIZRAHI                                                                           NaN
# RODRIGO PAOLIELLO DE MEDEIROS                                                          NaN
# LUCAS HIX                                                                              3.0
#
#                                          Qual nível de PROATIVIDADE cada membro teve na sprint anterior? (LEIA A RUBRICA, POIS ISSO NÃO É SIMPLESMENTE UMA NOTA)\n\nNa linha com o seu nome, faça a sua autoavaliação [PEDRO BALBO PORTELLA]
# Selecione o seu Nome
# TALES IVALQUE TAVEIRA DE FREITAS                                                       3.0                                                                                                                                                    \
# Gustavo Eliziario Stevenson de Oliveira                                                NaN
# LUCA MIZRAHI                                                                           NaN
# RODRIGO PAOLIELLO DE MEDEIROS                                                          NaN
# LUCAS HIX                                                                              3.0
#
#                                          Qual nível de PROATIVIDADE cada membro teve na sprint anterior? (LEIA A RUBRICA, POIS ISSO NÃO É SIMPLESMENTE UMA NOTA)\n\nNa linha com o seu nome, faça a sua autoavaliação [RAFAEL PASCARELLI NICCHERI]
# Selecione o seu Nome
# TALES IVALQUE TAVEIRA DE FREITAS                                                       3.0                                                                                                                                                          \
# Gustavo Eliziario Stevenson de Oliveira                                                NaN
# LUCA MIZRAHI                                                                           NaN
# RODRIGO PAOLIELLO DE MEDEIROS                                                          NaN
# LUCAS HIX                                                                              3.0
#
#                                          Qual nível de PROATIVIDADE cada membro teve na sprint anterior? (LEIA A RUBRICA, POIS ISSO NÃO É SIMPLESMENTE UMA NOTA)\n\nNa linha com o seu nome, faça a sua autoavaliação [TALES IVALQUE TAVEIRA DE FREITAS]
# Selecione o seu Nome
# TALES IVALQUE TAVEIRA DE FREITAS                                                       3.0                                                                                                                                                                \
# Gustavo Eliziario Stevenson de Oliveira                                                NaN
# LUCA MIZRAHI                                                                           NaN
# RODRIGO PAOLIELLO DE MEDEIROS                                                          NaN
# LUCAS HIX                                                                              3.0
#
#                                          Qual nível de TRANSPARÊNCIA cada membro teve na sprint anterior? (LEIA A RUBRICA, POIS ISSO NÃO É SIMPLESMENTE UMA NOTA)\n\nNa linha com o seu nome, faça a sua autoavaliação [LUCAS HIX]
# Selecione o seu Nome
# TALES IVALQUE TAVEIRA DE FREITAS                                                       3.0                                                                                                                                          \
# Gustavo Eliziario Stevenson de Oliveira                                                NaN
# LUCA MIZRAHI                                                                           NaN
# RODRIGO PAOLIELLO DE MEDEIROS                                                          NaN
# LUCAS HIX                                                                              3.0
#
#                                          Qual nível de TRANSPARÊNCIA cada membro teve na sprint anterior? (LEIA A RUBRICA, POIS ISSO NÃO É SIMPLESMENTE UMA NOTA)\n\nNa linha com o seu nome, faça a sua autoavaliação [PEDRO BALBO PORTELLA]
# Selecione o seu Nome
# TALES IVALQUE TAVEIRA DE FREITAS                                                       3.0                                                                                                                                                     \
# Gustavo Eliziario Stevenson de Oliveira                                                NaN
# LUCA MIZRAHI                                                                           NaN
# RODRIGO PAOLIELLO DE MEDEIROS                                                          NaN
# LUCAS HIX                                                                              3.0
#
#                                          Qual nível de TRANSPARÊNCIA cada membro teve na sprint anterior? (LEIA A RUBRICA, POIS ISSO NÃO É SIMPLESMENTE UMA NOTA)\n\nNa linha com o seu nome, faça a sua autoavaliação [RAFAEL PASCARELLI NICCHERI]
# Selecione o seu Nome
# TALES IVALQUE TAVEIRA DE FREITAS                                                       3.0                                                                                                                                                           \
# Gustavo Eliziario Stevenson de Oliveira                                                NaN
# LUCA MIZRAHI                                                                           NaN
# RODRIGO PAOLIELLO DE MEDEIROS                                                          NaN
# LUCAS HIX                                                                              3.0
#
#                                          Qual nível de TRANSPARÊNCIA cada membro teve na sprint anterior? (LEIA A RUBRICA, POIS ISSO NÃO É SIMPLESMENTE UMA NOTA)\n\nNa linha com o seu nome, faça a sua autoavaliação [TALES IVALQUE TAVEIRA DE FREITAS]
# Selecione o seu Nome
# TALES IVALQUE TAVEIRA DE FREITAS                                                       3.0
# Gustavo Eliziario Stevenson de Oliveira                                                NaN
# LUCA MIZRAHI                                                                           NaN
# RODRIGO PAOLIELLO DE MEDEIROS                                                          NaN
# LUCAS HIX                                                                              3.0
#
# [5 rows x 102 columns]

# %%
new_columns = {}
for column in columns:
    # posição das palavras 'PRODUTIVIDADE', 'PROATIVIDADE', 'TRANSPARÊNCIA' no nome da coluna
    categoria = column.split()[3]
    nome = column.split('[')[-1].replace(']','')
    #removendo texto desnecessário da coluna e renomeando no padrão ex: PRODUTIVIDADE - NOME DO ALUN@
    new_columns[column] = f'{categoria} - {nome}'

# %%
df.rename(columns=new_columns, inplace=True)

# %%
alunos = list(df.index)
#Dicionário para armazenar as médias para criar um novo dataframe
data = {
    'nome':[],
    'media_produtividade':[],
    'media_proatividade':[],
    'media_transparência':[],
    'auto_produtividade':[],
    'auto_proatividade':[],
    'auto_transparência':[],
    'media':[]
}

# %%
categorias = ['PRODUTIVIDADE', 'PROATIVIDADE', 'TRANSPARÊNCIA']
for aluno in alunos:
    data['nome'].append(aluno)
    soma = 0
    for categoria in categorias:
        nome_coluna = f'{categoria} - {aluno}'
        media_colegas = df.loc[(df.index != aluno) ,nome_coluna].dropna().mean()
        soma += media_colegas
        
        auto_avaliacao = df.loc[(df.index == aluno) ,nome_coluna][0]
        
        data[f'media_{categoria.lower()}'].append(media_colegas)
        data[f'auto_{categoria.lower()}'].append(auto_avaliacao)
    data['media'].append(soma/3)

# %%
# data

# %%
df_medias = pd.DataFrame(data=data)

# %%
df_medias['dif_produtividade'] = df_medias['media_produtividade'] - df_medias['auto_produtividade']
df_medias['dif_proatividade'] = df_medias['media_proatividade'] - df_medias['auto_proatividade']
df_medias['dif_transparência'] = df_medias['media_transparência'] - df_medias['auto_transparência']

# %%
df_medias.loc[:,['nome','dif_produtividade','dif_proatividade','dif_transparência']]
# Out:
#                                        nome  dif_produtividade
# 0          TALES IVALQUE TAVEIRA DE FREITAS           0.000000  \
# 1   Gustavo Eliziario Stevenson de Oliveira           0.500000
# 2                              LUCA MIZRAHI           0.500000
# 3             RODRIGO PAOLIELLO DE MEDEIROS           0.000000
# 4                                 LUCAS HIX           0.000000
# 5               JOÃO PEDRO RODRIGUES SANTOS           0.000000
# 6                       ARTHUR MOREIRA TAMM           0.000000
# 7                     LUANA WILNER ABRAMOFF           0.000000
# 8                       BRUNA LIMA MEINBERG           0.000000
# 9                        DIOGO PEREIRA LOBO           0.500000
# 10            ISABELLA DOS SANTOS DE AMORIM           0.000000
# 11        GABRIEL MENDONÇA DE MELLO HERMIDA           0.000000
# 12                 PEDRO TOLEDO PIZA CIVITA           0.000000
# 13     PEDRO AUGUSTO GEVE DE MORAES LACERDA           0.000000
# 14                ANA LAIZ NOVAIS DE FARIAS          -0.500000
# 15                  GUSTAVO MENDES DA SILVA          -0.500000
# 16           ALEXANDRE RODRIGUES SANTAROSSA          -0.500000
# 17                    PEDRO IVO AMARAL LIMA           0.000000
# 18                     GABRIELA KATSURAYAMA           1.000000
# 19                     NICOLAS ENZO YASSUDA           0.000000
# 20                JOÃO ANTÔNIO GOMES GARCIA           0.000000
# 21            BRUNO MARQUES LI VOLSI FALCAO           0.000000
# 22                 LUCAS NOVAIS DE OLIVEIRA          -0.500000
# 23       MATHEUS RAFFAELLE NERY CASTELLUCCI           0.000000
# 24               PEDRO HENRIQUE RIZO COLPAS           0.000000
# 25                PEDRO GOMES DE SÁ DRUMOND           0.000000
# 26          ALBERTO MARTINS PEREIRA CARRERA           0.000000
# 27                            DOUGLAS PABLO           0.333333
# 28                     PEDRO BALBO PORTELLA           0.000000
# 29               RAFAEL PASCARELLI NICCHERI           0.000000
#
#     dif_proatividade  dif_transparência
# 0                0.0                0.0
# 1                1.0                1.0
# 2                1.0                1.0
# 3                0.0                0.0
# 4                0.0                0.0
# 5                0.0                0.0
# 6                0.0                0.0
# 7                0.0                0.0
# 8                0.0                0.0
# 9                0.5                0.5
# 10              -0.5               -0.5
# 11               0.0                0.0
# 12               0.0                0.0
# 13               0.0                0.0
# 14              -1.0               -1.0
# 15              -0.5               -0.5
# 16               0.0               -0.5
# 17               0.0                0.0
# 18               1.0                1.0
# 19               0.0                0.0
# 20               0.0                0.0
# 21              -2.0               -2.0
# 22              -0.5               -0.5
# 23               0.0                0.0
# 24               0.0                1.0
# 25               0.0                0.0
# 26               0.0                0.0
# 27               0.0                0.0
# 28               0.0                0.0
# 29               0.0                0.0

# %% [markdown]
# # Verificando respostas duplicadas

# %%
#fazer algo para identificar alunos que responderam o formulário mais de uma vez e pegar a última resposta
#verificar pessoas que não responderam

# %%
df_count = df_medias.groupby(['nome'])['nome'].count().to_frame('count')
df_count.loc[df_count["count"]>1,:]
# Out:
# Empty DataFrame
# Columns: [count]
# Index: []

# %% [markdown]
# # Salvando em arquivo

# %% [markdown]
# df_medias.to_excel('sprint1_medias.xlsx')

# %%
df_medias.shape
# Out:
# (30, 11)

# %%
df.shape
# Out:
# (30, 102)
