# %%
from __future__ import print_function

import base64
from email.message import EmailMessage

import google.auth
from googleapiclient.discovery import build
from googleapiclient.errors import HttpError

# %% [markdown]
# from google.oauth2 import service_account
# from googleapiclient.discovery import build
#
#
# credentials = service_account.Credentials.from_service_account_file(
#   '$HOME/.config/gcloud/application_default_credentials.json'
# )

# %%
def gmail_create_draft():
    """Create and insert a draft email.
       Print the returned draft's message and id.
       Returns: Draft object, including draft id and message meta data.

      Load pre-authorized user credentials from the environment.
      TODO(developer) - See https://developers.google.com/identity
      for guides on implementing OAuth2 for the application.
    """
    creds, _ = google.auth.default()

    try:
        # create gmail api client
        service = build('gmail', 'v1', credentials=creds)

        message = EmailMessage()

        message.set_content('This is automated draft mail')

        message['To'] = 'barbarata@insper.edu.br'
        message['From'] = 'barbara.tieko@gmail.com'
        message['Subject'] = 'Automated draft'

        # encoded message
        encoded_message = base64.urlsafe_b64encode(message.as_bytes()).decode()

        create_message = {
            'message': {
                'raw': encoded_message
            }
        }
        # pylint: disable=E1101
        draft = service.users().drafts().create(userId="me",
                                                body=create_message).execute()

        print(F'Draft id: {draft["id"]}\nDraft message: {draft["message"]}')

    except HttpError as error:
        print(F'An error occurred: {error}')
        draft = None

    return draft


if __name__ == '__main__':
    gmail_create_draft()
# Out:
# ---------------------------------------------------------------------------
# DefaultCredentialsError                   Traceback (most recent call last)
# Cell In[8], line 46
#      42     return draft
#      45 if __name__ == '__main__':
# ---> 46     gmail_create_draft()
#
# Cell In[8], line 10, in gmail_create_draft()
#       1 def gmail_create_draft():
#       2     """Create and insert a draft email.
#       3        Print the returned draft's message and id.
#       4        Returns: Draft object, including draft id and message meta data.
#    (...)
#       8       for guides on implementing OAuth2 for the application.
#       9     """
# ---> 10     creds, _ = google.auth.default()
#      12     try:
#      13         # create gmail api client
#      14         service = build('gmail', 'v1', credentials=creds)
#
# File ~/Desktop/2023.1/tecweb/tecweb.2023.1/projeto3/2023.1/env/lib/python3.11/site-packages/google/auth/_default.py:648, in default(scopes, request, quota_project_id, default_scopes)
#     640             _LOGGER.warning(
#     641                 "No project ID could be determined. Consider running "
#     642                 "`gcloud config set project` or setting the %s "
#     643                 "environment variable",
#     644                 environment_vars.PROJECT,
#     645             )
#     646         return credentials, effective_project_id
# --> 648 raise exceptions.DefaultCredentialsError(_CLOUD_SDK_MISSING_CREDENTIALS)
#
# DefaultCredentialsError: Your default credentials were not found. To set up Application Default Credentials, see https://cloud.google.com/docs/authentication/external/set-up-adc for more information.
