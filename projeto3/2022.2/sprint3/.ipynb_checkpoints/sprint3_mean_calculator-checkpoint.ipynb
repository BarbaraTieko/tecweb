# %%
import pandas as pd

# %%
# !ls
# Out:
# Análise.ipynb
# Avaliação Individual dos Membros (Responses).xlsx
# sprint3_feedback.ipynb
# sprint3_mean_calculator.ipynb

# %%
df = pd.read_excel('Avaliação Individual dos Membros (Responses).xlsx')

# %%
df.set_index('Selecione o seu Nome', inplace=True)
df.drop(['Timestamp'], axis=1, inplace=True)

# %%
columns = df.columns

# %%
df
# Out:
#                                      Qual nível de PRODUTIVIDADE cada membro teve na sprint anterior? (LEIA A RUBRICA, POIS ISSO NÃO É SIMPLESMENTE UMA NOTA)\n\nNa linha com o seu nome, faça a sua autoavaliação [ALBERTO MANSUR]  \
# Selecione o seu Nome
# PEDRO BITTAR BARÃO                                                                 NaN
# ENRICCO GEMHA                                                                      NaN
# HUDSON MONTEIRO                                                                    NaN
# PEDRO PAULO MORENO CAMARGO                                                         NaN
# DOM RUAN SUZANO FIGUEIRA DA SILVA                                                  NaN
# GIOVANA CASSONI ANDRADE                                                            NaN
# ANTÔNIO AMARAL EGYDIO MARTINS                                                      NaN
# MURILO PRADO WEYNE                                                                 NaN
# CAIO TRAVAIN                                                                       NaN
# FELIPE CATAPANO                                                                    3.0
# RAFAEL ELI KATRI                                                                   3.0
# VINICIUS MATHEUS MORALES                                                           NaN
# CAIO RIBEIRO DE PAULA                                                              NaN
# FERNANDO GIUSEPPE AVILA BELTRAMO                                                   3.0
# LEONARDO DA FRANÇA MOURA DE ANDRADE                                                NaN
# RODRIGO ANCIÃES PATELLI                                                            NaN
# GUILHERME DOS SANTOS MARTINS                                                       NaN
# MARLON SILVA PEREIRA                                                               NaN
# ARIEL TAMEZGUI LEVENTHAL                                                           NaN
# ARTHUR MARTINS DE SOUZA BARRETO                                                    NaN
# PEDRO CLIQUET DO AMARAL                                                            NaN
# FERNANDA DE OLIVEIRA PEREIRA                                                       NaN
# ANDRÉ CORRÊA SANTOS                                                                NaN
# JOÃO GABRIEL VALENTIM ROCHA                                                        NaN
# LINCOLN RODRIGO PEREIRA MELO                                                       NaN
# ANDRÉ BRITO                                                                        NaN
#
#                                      Qual nível de PRODUTIVIDADE cada membro teve na sprint anterior? (LEIA A RUBRICA, POIS ISSO NÃO É SIMPLESMENTE UMA NOTA)\n\nNa linha com o seu nome, faça a sua autoavaliação [FELIPE CATAPANO]  \
# Selecione o seu Nome
# PEDRO BITTAR BARÃO                                                                 NaN
# ENRICCO GEMHA                                                                      NaN
# HUDSON MONTEIRO                                                                    NaN
# PEDRO PAULO MORENO CAMARGO                                                         NaN
# DOM RUAN SUZANO FIGUEIRA DA SILVA                                                  NaN
# GIOVANA CASSONI ANDRADE                                                            NaN
# ANTÔNIO AMARAL EGYDIO MARTINS                                                      NaN
# MURILO PRADO WEYNE                                                                 NaN
# CAIO TRAVAIN                                                                       NaN
# FELIPE CATAPANO                                                                    4.0
# RAFAEL ELI KATRI                                                                   3.0
# VINICIUS MATHEUS MORALES                                                           NaN
# CAIO RIBEIRO DE PAULA                                                              NaN
# FERNANDO GIUSEPPE AVILA BELTRAMO                                                   3.0
# LEONARDO DA FRANÇA MOURA DE ANDRADE                                                NaN
# RODRIGO ANCIÃES PATELLI                                                            NaN
# GUILHERME DOS SANTOS MARTINS                                                       NaN
# MARLON SILVA PEREIRA                                                               NaN
# ARIEL TAMEZGUI LEVENTHAL                                                           NaN
# ARTHUR MARTINS DE SOUZA BARRETO                                                    NaN
# PEDRO CLIQUET DO AMARAL                                                            NaN
# FERNANDA DE OLIVEIRA PEREIRA                                                       NaN
# ANDRÉ CORRÊA SANTOS                                                                NaN
# JOÃO GABRIEL VALENTIM ROCHA                                                        NaN
# LINCOLN RODRIGO PEREIRA MELO                                                       NaN
# ANDRÉ BRITO                                                                        NaN
#
#                                      Qual nível de PRODUTIVIDADE cada membro teve na sprint anterior? (LEIA A RUBRICA, POIS ISSO NÃO É SIMPLESMENTE UMA NOTA)\n\nNa linha com o seu nome, faça a sua autoavaliação [FERNANDO GIUSEPPE AVILA BELTRAMO]  \
# Selecione o seu Nome
# PEDRO BITTAR BARÃO                                                                 NaN
# ENRICCO GEMHA                                                                      NaN
# HUDSON MONTEIRO                                                                    NaN
# PEDRO PAULO MORENO CAMARGO                                                         NaN
# DOM RUAN SUZANO FIGUEIRA DA SILVA                                                  NaN
# GIOVANA CASSONI ANDRADE                                                            NaN
# ANTÔNIO AMARAL EGYDIO MARTINS                                                      NaN
# MURILO PRADO WEYNE                                                                 NaN
# CAIO TRAVAIN                                                                       NaN
# FELIPE CATAPANO                                                                    3.0
# RAFAEL ELI KATRI                                                                   3.0
# VINICIUS MATHEUS MORALES                                                           NaN
# CAIO RIBEIRO DE PAULA                                                              NaN
# FERNANDO GIUSEPPE AVILA BELTRAMO                                                   3.0
# LEONARDO DA FRANÇA MOURA DE ANDRADE                                                NaN
# RODRIGO ANCIÃES PATELLI                                                            NaN
# GUILHERME DOS SANTOS MARTINS                                                       NaN
# MARLON SILVA PEREIRA                                                               NaN
# ARIEL TAMEZGUI LEVENTHAL                                                           NaN
# ARTHUR MARTINS DE SOUZA BARRETO                                                    NaN
# PEDRO CLIQUET DO AMARAL                                                            NaN
# FERNANDA DE OLIVEIRA PEREIRA                                                       NaN
# ANDRÉ CORRÊA SANTOS                                                                NaN
# JOÃO GABRIEL VALENTIM ROCHA                                                        NaN
# LINCOLN RODRIGO PEREIRA MELO                                                       NaN
# ANDRÉ BRITO                                                                        NaN
#
#                                      Qual nível de PRODUTIVIDADE cada membro teve na sprint anterior? (LEIA A RUBRICA, POIS ISSO NÃO É SIMPLESMENTE UMA NOTA)\n\nNa linha com o seu nome, faça a sua autoavaliação [RAFAEL ELI KATRI]  \
# Selecione o seu Nome
# PEDRO BITTAR BARÃO                                                                 NaN
# ENRICCO GEMHA                                                                      NaN
# HUDSON MONTEIRO                                                                    NaN
# PEDRO PAULO MORENO CAMARGO                                                         NaN
# DOM RUAN SUZANO FIGUEIRA DA SILVA                                                  NaN
# GIOVANA CASSONI ANDRADE                                                            NaN
# ANTÔNIO AMARAL EGYDIO MARTINS                                                      NaN
# MURILO PRADO WEYNE                                                                 NaN
# CAIO TRAVAIN                                                                       NaN
# FELIPE CATAPANO                                                                    3.0
# RAFAEL ELI KATRI                                                                   3.0
# VINICIUS MATHEUS MORALES                                                           NaN
# CAIO RIBEIRO DE PAULA                                                              NaN
# FERNANDO GIUSEPPE AVILA BELTRAMO                                                   3.0
# LEONARDO DA FRANÇA MOURA DE ANDRADE                                                NaN
# RODRIGO ANCIÃES PATELLI                                                            NaN
# GUILHERME DOS SANTOS MARTINS                                                       NaN
# MARLON SILVA PEREIRA                                                               NaN
# ARIEL TAMEZGUI LEVENTHAL                                                           NaN
# ARTHUR MARTINS DE SOUZA BARRETO                                                    NaN
# PEDRO CLIQUET DO AMARAL                                                            NaN
# FERNANDA DE OLIVEIRA PEREIRA                                                       NaN
# ANDRÉ CORRÊA SANTOS                                                                NaN
# JOÃO GABRIEL VALENTIM ROCHA                                                        NaN
# LINCOLN RODRIGO PEREIRA MELO                                                       NaN
# ANDRÉ BRITO                                                                        NaN
#
#                                      Qual nível de PROATIVIDADE cada membro teve na sprint anterior? (LEIA A RUBRICA, POIS ISSO NÃO É SIMPLESMENTE UMA NOTA)\n\nNa linha com o seu nome, faça a sua autoavaliação [ALBERTO MANSUR]  \
# Selecione o seu Nome
# PEDRO BITTAR BARÃO                                                                 NaN
# ENRICCO GEMHA                                                                      NaN
# HUDSON MONTEIRO                                                                    NaN
# PEDRO PAULO MORENO CAMARGO                                                         NaN
# DOM RUAN SUZANO FIGUEIRA DA SILVA                                                  NaN
# GIOVANA CASSONI ANDRADE                                                            NaN
# ANTÔNIO AMARAL EGYDIO MARTINS                                                      NaN
# MURILO PRADO WEYNE                                                                 NaN
# CAIO TRAVAIN                                                                       NaN
# FELIPE CATAPANO                                                                    3.0
# RAFAEL ELI KATRI                                                                   3.0
# VINICIUS MATHEUS MORALES                                                           NaN
# CAIO RIBEIRO DE PAULA                                                              NaN
# FERNANDO GIUSEPPE AVILA BELTRAMO                                                   3.0
# LEONARDO DA FRANÇA MOURA DE ANDRADE                                                NaN
# RODRIGO ANCIÃES PATELLI                                                            NaN
# GUILHERME DOS SANTOS MARTINS                                                       NaN
# MARLON SILVA PEREIRA                                                               NaN
# ARIEL TAMEZGUI LEVENTHAL                                                           NaN
# ARTHUR MARTINS DE SOUZA BARRETO                                                    NaN
# PEDRO CLIQUET DO AMARAL                                                            NaN
# FERNANDA DE OLIVEIRA PEREIRA                                                       NaN
# ANDRÉ CORRÊA SANTOS                                                                NaN
# JOÃO GABRIEL VALENTIM ROCHA                                                        NaN
# LINCOLN RODRIGO PEREIRA MELO                                                       NaN
# ANDRÉ BRITO                                                                        NaN
#
#                                      Qual nível de PROATIVIDADE cada membro teve na sprint anterior? (LEIA A RUBRICA, POIS ISSO NÃO É SIMPLESMENTE UMA NOTA)\n\nNa linha com o seu nome, faça a sua autoavaliação [FELIPE CATAPANO]  \
# Selecione o seu Nome
# PEDRO BITTAR BARÃO                                                                 NaN
# ENRICCO GEMHA                                                                      NaN
# HUDSON MONTEIRO                                                                    NaN
# PEDRO PAULO MORENO CAMARGO                                                         NaN
# DOM RUAN SUZANO FIGUEIRA DA SILVA                                                  NaN
# GIOVANA CASSONI ANDRADE                                                            NaN
# ANTÔNIO AMARAL EGYDIO MARTINS                                                      NaN
# MURILO PRADO WEYNE                                                                 NaN
# CAIO TRAVAIN                                                                       NaN
# FELIPE CATAPANO                                                                    4.0
# RAFAEL ELI KATRI                                                                   3.0
# VINICIUS MATHEUS MORALES                                                           NaN
# CAIO RIBEIRO DE PAULA                                                              NaN
# FERNANDO GIUSEPPE AVILA BELTRAMO                                                   3.0
# LEONARDO DA FRANÇA MOURA DE ANDRADE                                                NaN
# RODRIGO ANCIÃES PATELLI                                                            NaN
# GUILHERME DOS SANTOS MARTINS                                                       NaN
# MARLON SILVA PEREIRA                                                               NaN
# ARIEL TAMEZGUI LEVENTHAL                                                           NaN
# ARTHUR MARTINS DE SOUZA BARRETO                                                    NaN
# PEDRO CLIQUET DO AMARAL                                                            NaN
# FERNANDA DE OLIVEIRA PEREIRA                                                       NaN
# ANDRÉ CORRÊA SANTOS                                                                NaN
# JOÃO GABRIEL VALENTIM ROCHA                                                        NaN
# LINCOLN RODRIGO PEREIRA MELO                                                       NaN
# ANDRÉ BRITO                                                                        NaN
#
#                                      Qual nível de PROATIVIDADE cada membro teve na sprint anterior? (LEIA A RUBRICA, POIS ISSO NÃO É SIMPLESMENTE UMA NOTA)\n\nNa linha com o seu nome, faça a sua autoavaliação [FERNANDO GIUSEPPE AVILA BELTRAMO]  \
# Selecione o seu Nome
# PEDRO BITTAR BARÃO                                                                 NaN
# ENRICCO GEMHA                                                                      NaN
# HUDSON MONTEIRO                                                                    NaN
# PEDRO PAULO MORENO CAMARGO                                                         NaN
# DOM RUAN SUZANO FIGUEIRA DA SILVA                                                  NaN
# GIOVANA CASSONI ANDRADE                                                            NaN
# ANTÔNIO AMARAL EGYDIO MARTINS                                                      NaN
# MURILO PRADO WEYNE                                                                 NaN
# CAIO TRAVAIN                                                                       NaN
# FELIPE CATAPANO                                                                    3.0
# RAFAEL ELI KATRI                                                                   3.0
# VINICIUS MATHEUS MORALES                                                           NaN
# CAIO RIBEIRO DE PAULA                                                              NaN
# FERNANDO GIUSEPPE AVILA BELTRAMO                                                   3.0
# LEONARDO DA FRANÇA MOURA DE ANDRADE                                                NaN
# RODRIGO ANCIÃES PATELLI                                                            NaN
# GUILHERME DOS SANTOS MARTINS                                                       NaN
# MARLON SILVA PEREIRA                                                               NaN
# ARIEL TAMEZGUI LEVENTHAL                                                           NaN
# ARTHUR MARTINS DE SOUZA BARRETO                                                    NaN
# PEDRO CLIQUET DO AMARAL                                                            NaN
# FERNANDA DE OLIVEIRA PEREIRA                                                       NaN
# ANDRÉ CORRÊA SANTOS                                                                NaN
# JOÃO GABRIEL VALENTIM ROCHA                                                        NaN
# LINCOLN RODRIGO PEREIRA MELO                                                       NaN
# ANDRÉ BRITO                                                                        NaN
#
#                                      Qual nível de PROATIVIDADE cada membro teve na sprint anterior? (LEIA A RUBRICA, POIS ISSO NÃO É SIMPLESMENTE UMA NOTA)\n\nNa linha com o seu nome, faça a sua autoavaliação [RAFAEL ELI KATRI]  \
# Selecione o seu Nome
# PEDRO BITTAR BARÃO                                                                 NaN
# ENRICCO GEMHA                                                                      NaN
# HUDSON MONTEIRO                                                                    NaN
# PEDRO PAULO MORENO CAMARGO                                                         NaN
# DOM RUAN SUZANO FIGUEIRA DA SILVA                                                  NaN
# ...
# GUILHERME DOS SANTOS MARTINS                                                       NaN
# MARLON SILVA PEREIRA                                                               NaN
# ARIEL TAMEZGUI LEVENTHAL                                                           NaN
# ARTHUR MARTINS DE SOUZA BARRETO                                                    NaN
# PEDRO CLIQUET DO AMARAL                                                            3.0
# FERNANDA DE OLIVEIRA PEREIRA                                                       NaN
# ANDRÉ CORRÊA SANTOS                                                                NaN
# JOÃO GABRIEL VALENTIM ROCHA                                                        NaN
# LINCOLN RODRIGO PEREIRA MELO                                                       3.0
# ANDRÉ BRITO                                                                        NaN
#
#                                      Qual nível de TRANSPARÊNCIA cada membro teve na sprint anterior? (LEIA A RUBRICA, POIS ISSO NÃO É SIMPLESMENTE UMA NOTA)\n\nNa linha com o seu nome, faça a sua autoavaliação [PEDRO CLIQUET DO AMARAL]  \
# Selecione o seu Nome
# PEDRO BITTAR BARÃO                                                                 NaN
# ENRICCO GEMHA                                                                      NaN
# HUDSON MONTEIRO                                                                    NaN
# PEDRO PAULO MORENO CAMARGO                                                         NaN
# DOM RUAN SUZANO FIGUEIRA DA SILVA                                                  NaN
# GIOVANA CASSONI ANDRADE                                                            NaN
# ANTÔNIO AMARAL EGYDIO MARTINS                                                      NaN
# MURILO PRADO WEYNE                                                                 NaN
# CAIO TRAVAIN                                                                       NaN
# FELIPE CATAPANO                                                                    NaN
# RAFAEL ELI KATRI                                                                   NaN
# VINICIUS MATHEUS MORALES                                                           3.0
# CAIO RIBEIRO DE PAULA                                                              NaN
# FERNANDO GIUSEPPE AVILA BELTRAMO                                                   NaN
# LEONARDO DA FRANÇA MOURA DE ANDRADE                                                NaN
# RODRIGO ANCIÃES PATELLI                                                            NaN
# GUILHERME DOS SANTOS MARTINS                                                       NaN
# MARLON SILVA PEREIRA                                                               NaN
# ARIEL TAMEZGUI LEVENTHAL                                                           NaN
# ARTHUR MARTINS DE SOUZA BARRETO                                                    NaN
# PEDRO CLIQUET DO AMARAL                                                            3.0
# FERNANDA DE OLIVEIRA PEREIRA                                                       NaN
# ANDRÉ CORRÊA SANTOS                                                                NaN
# JOÃO GABRIEL VALENTIM ROCHA                                                        NaN
# LINCOLN RODRIGO PEREIRA MELO                                                       3.0
# ANDRÉ BRITO                                                                        NaN
#
#                                      Qual nível de TRANSPARÊNCIA cada membro teve na sprint anterior? (LEIA A RUBRICA, POIS ISSO NÃO É SIMPLESMENTE UMA NOTA)\n\nNa linha com o seu nome, faça a sua autoavaliação [VINICIUS MATHEUS MORALES]
# Selecione o seu Nome
# PEDRO BITTAR BARÃO                                                                 NaN
# ENRICCO GEMHA                                                                      NaN
# HUDSON MONTEIRO                                                                    NaN
# PEDRO PAULO MORENO CAMARGO                                                         NaN
# DOM RUAN SUZANO FIGUEIRA DA SILVA                                                  NaN
# GIOVANA CASSONI ANDRADE                                                            NaN
# ANTÔNIO AMARAL EGYDIO MARTINS                                                      NaN
# MURILO PRADO WEYNE                                                                 NaN
# CAIO TRAVAIN                                                                       NaN
# FELIPE CATAPANO                                                                    NaN
# RAFAEL ELI KATRI                                                                   NaN
# VINICIUS MATHEUS MORALES                                                           3.0
# CAIO RIBEIRO DE PAULA                                                              NaN
# FERNANDO GIUSEPPE AVILA BELTRAMO                                                   NaN
# LEONARDO DA FRANÇA MOURA DE ANDRADE                                                NaN
# RODRIGO ANCIÃES PATELLI                                                            NaN
# GUILHERME DOS SANTOS MARTINS                                                       NaN
# MARLON SILVA PEREIRA                                                               NaN
# ARIEL TAMEZGUI LEVENTHAL                                                           NaN
# ARTHUR MARTINS DE SOUZA BARRETO                                                    NaN
# PEDRO CLIQUET DO AMARAL                                                            3.0
# FERNANDA DE OLIVEIRA PEREIRA                                                       NaN
# ANDRÉ CORRÊA SANTOS                                                                NaN
# JOÃO GABRIEL VALENTIM ROCHA                                                        NaN
# LINCOLN RODRIGO PEREIRA MELO                                                       3.0
# ANDRÉ BRITO                                                                        NaN
#
# [26 rows x 120 columns]

# %%
new_columns = {}
for column in columns:
    # posição das palavras 'PRODUTIVIDADE', 'PROATIVIDADE', 'TRANSPARÊNCIA' no nome da coluna
    categoria = column.split()[3]
    nome = column.split('[')[-1].replace(']','')
    #removendo texto desnecessário da coluna e renomeando no padrão ex: PRODUTIVIDADE - NOME DO ALUN@
    new_columns[column] = f'{categoria} - {nome}'

# %%
df.rename(columns=new_columns, inplace=True)

# %%
alunos = list(df.index)
#Dicionário para armazenar as médias para criar um novo dataframe
data = {
    'nome':[],
    'media_produtividade':[],
    'media_proatividade':[],
    'media_transparência':[],
    'auto_produtividade':[],
    'auto_proatividade':[],
    'auto_transparência':[],
    'media':[]
}

# %%
categorias = ['PRODUTIVIDADE', 'PROATIVIDADE', 'TRANSPARÊNCIA']
for aluno in alunos:
    data['nome'].append(aluno)
    soma = 0
    for categoria in categorias:
        nome_coluna = f'{categoria} - {aluno}'
        media_colegas = df.loc[(df.index != aluno) ,nome_coluna].dropna().mean()
        soma += media_colegas
        
        auto_avaliacao = df.loc[(df.index == aluno) ,nome_coluna][0]
        
        data[f'media_{categoria.lower()}'].append(media_colegas)
        data[f'auto_{categoria.lower()}'].append(auto_avaliacao)
    data['media'].append(soma/3)

# %%
# data

# %%
df_medias = pd.DataFrame(data=data)

# %%
df_medias['dif_produtividade'] = df_medias['media_produtividade'] - df_medias['auto_produtividade']
df_medias['dif_proatividade'] = df_medias['media_proatividade'] - df_medias['auto_proatividade']
df_medias['dif_transparência'] = df_medias['media_transparência'] - df_medias['auto_transparência']

# %%
df_medias.loc[:,['nome','dif_produtividade','dif_proatividade','dif_transparência']]
# Out:
#                                    nome  dif_produtividade  dif_proatividade  \
# 0                    PEDRO BITTAR BARÃO           0.000000          0.000000
# 1                         ENRICCO GEMHA           1.000000          1.000000
# 2                       HUDSON MONTEIRO           0.000000          0.000000
# 3            PEDRO PAULO MORENO CAMARGO           0.000000          0.000000
# 4     DOM RUAN SUZANO FIGUEIRA DA SILVA           0.000000          0.000000
# 5               GIOVANA CASSONI ANDRADE           0.000000          0.333333
# 6         ANTÔNIO AMARAL EGYDIO MARTINS           0.333333         -0.666667
# 7                    MURILO PRADO WEYNE           0.333333          0.666667
# 8                          CAIO TRAVAIN           0.000000          1.000000
# 9                       FELIPE CATAPANO          -1.000000         -1.000000
# 10                     RAFAEL ELI KATRI           0.000000          0.000000
# 11             VINICIUS MATHEUS MORALES           0.000000          0.000000
# 12                CAIO RIBEIRO DE PAULA           0.000000          0.000000
# 13     FERNANDO GIUSEPPE AVILA BELTRAMO           0.000000          0.000000
# 14  LEONARDO DA FRANÇA MOURA DE ANDRADE           0.000000         -1.000000
# 15              RODRIGO ANCIÃES PATELLI           1.000000          1.000000
# 16         GUILHERME DOS SANTOS MARTINS           0.000000          0.000000
# 17                 MARLON SILVA PEREIRA           0.333333          0.333333
# 18             ARIEL TAMEZGUI LEVENTHAL           0.333333          0.666667
# 19      ARTHUR MARTINS DE SOUZA BARRETO          -1.000000         -0.666667
# 20              PEDRO CLIQUET DO AMARAL           0.000000          0.000000
# 21         FERNANDA DE OLIVEIRA PEREIRA           0.000000          0.000000
# 22                  ANDRÉ CORRÊA SANTOS          -1.000000          0.000000
# 23          JOÃO GABRIEL VALENTIM ROCHA           0.000000          0.000000
# 24         LINCOLN RODRIGO PEREIRA MELO          -0.500000          0.000000
# 25                          ANDRÉ BRITO                NaN               NaN
#
#     dif_transparência
# 0            0.000000
# 1            1.000000
# 2            0.000000
# 3            0.000000
# 4            0.000000
# 5            0.000000
# 6            0.333333
# 7            0.333333
# 8            1.000000
# 9           -1.000000
# 10           0.000000
# 11           0.000000
# 12           0.000000
# 13           0.000000
# 14           0.000000
# 15           0.000000
# 16           0.000000
# 17           0.000000
# 18           0.333333
# 19          -1.000000
# 20           0.000000
# 21           0.000000
# 22           0.000000
# 23           0.000000
# 24           0.000000
# 25                NaN

# %%
df_medias.to_excel('sprint3_medias.xlsx')
