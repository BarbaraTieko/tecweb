# %%
import pandas as pd

# %%
df = pd.read_excel('responses_copy.xlsx')

# %%
df.head()
# Out:
#                 Timestamp              Selecione o seu Nome  \
# 0 2022-11-24 18:33:51.957  FERNANDO GIUSEPPE AVILA BELTRAMO
# 1 2022-11-24 18:42:48.613          ERIC ANDREI LIMA POSSATO
# 2 2022-11-24 19:11:26.298      GUILHERME DOS SANTOS MARTINS
# 3 2022-11-24 19:43:36.207        PEDRO PAULO MORENO CAMARGO
# 4 2022-11-24 19:45:38.156               ANDRÉ CORRÊA SANTOS
#
#    Qual nível de PRODUTIVIDADE cada membro teve na sprint anterior? (LEIA A RUBRICA, POIS ISSO NÃO É SIMPLESMENTE UMA NOTA)\n\nNa linha com o seu nome, faça a sua autoavaliação [ANDRÉ CORRÊA SANTOS]  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                3.0
# 4                                                3.0
#
#    Qual nível de PRODUTIVIDADE cada membro teve na sprint anterior? (LEIA A RUBRICA, POIS ISSO NÃO É SIMPLESMENTE UMA NOTA)\n\nNa linha com o seu nome, faça a sua autoavaliação [PEDRO PAULO MORENO CAMARGO]  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                3.0
# 4                                                3.0
#
#    Qual nível de PRODUTIVIDADE cada membro teve na sprint anterior? (LEIA A RUBRICA, POIS ISSO NÃO É SIMPLESMENTE UMA NOTA)\n\nNa linha com o seu nome, faça a sua autoavaliação [RAFAEL MELHADO ARAUJO LIMA]  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                3.0
# 4                                                3.0
#
#    Qual nível de PRODUTIVIDADE cada membro teve na sprint anterior? (LEIA A RUBRICA, POIS ISSO NÃO É SIMPLESMENTE UMA NOTA)\n\nNa linha com o seu nome, faça a sua autoavaliação [ANDRÉ BARBOZA BRAGA DE MELO]  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                3.0
# 4                                                3.0
#
#    Qual nível de PROATIVIDADE cada membro teve na sprint anterior? (LEIA A RUBRICA, POIS ISSO NÃO É SIMPLESMENTE UMA NOTA)\n\nNa linha com o seu nome, faça a sua autoavaliação [ANDRÉ CORRÊA SANTOS]  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                3.0
# 4                                                3.0
#
#    Qual nível de PROATIVIDADE cada membro teve na sprint anterior? (LEIA A RUBRICA, POIS ISSO NÃO É SIMPLESMENTE UMA NOTA)\n\nNa linha com o seu nome, faça a sua autoavaliação [PEDRO PAULO MORENO CAMARGO]  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                3.0
# 4                                                3.0
#
#    Qual nível de PROATIVIDADE cada membro teve na sprint anterior? (LEIA A RUBRICA, POIS ISSO NÃO É SIMPLESMENTE UMA NOTA)\n\nNa linha com o seu nome, faça a sua autoavaliação [RAFAEL MELHADO ARAUJO LIMA]  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                3.0
# 4                                                3.0
#
#    Qual nível de PROATIVIDADE cada membro teve na sprint anterior? (LEIA A RUBRICA, POIS ISSO NÃO É SIMPLESMENTE UMA NOTA)\n\nNa linha com o seu nome, faça a sua autoavaliação [ANDRÉ BARBOZA BRAGA DE MELO]  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                3.0
# 4                                                3.0
#
#    ...  \
# 0  ...
# 1  ...
# 2  ...
# 3  ...
# 4  ...
#
#    Qual nível de PRODUTIVIDADE cada membro teve na sprint anterior? (LEIA A RUBRICA, POIS ISSO NÃO É SIMPLESMENTE UMA NOTA)\n\nNa linha com o seu nome, faça a sua autoavaliação [CAIO DE CAMARGO ARANHA TIERI]  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    Qual nível de PRODUTIVIDADE cada membro teve na sprint anterior? (LEIA A RUBRICA, POIS ISSO NÃO É SIMPLESMENTE UMA NOTA)\n\nNa linha com o seu nome, faça a sua autoavaliação [FELIPE TRINTIM]  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    Qual nível de PROATIVIDADE cada membro teve na sprint anterior? (LEIA A RUBRICA, POIS ISSO NÃO É SIMPLESMENTE UMA NOTA)\n\nNa linha com o seu nome, faça a sua autoavaliação [THOMAS CHABRO]  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    Qual nível de PROATIVIDADE cada membro teve na sprint anterior? (LEIA A RUBRICA, POIS ISSO NÃO É SIMPLESMENTE UMA NOTA)\n\nNa linha com o seu nome, faça a sua autoavaliação [RAFAEL COCA LEVENTHAL]  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    Qual nível de PROATIVIDADE cada membro teve na sprint anterior? (LEIA A RUBRICA, POIS ISSO NÃO É SIMPLESMENTE UMA NOTA)\n\nNa linha com o seu nome, faça a sua autoavaliação [CAIO DE CAMARGO ARANHA TIERI]  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    Qual nível de PROATIVIDADE cada membro teve na sprint anterior? (LEIA A RUBRICA, POIS ISSO NÃO É SIMPLESMENTE UMA NOTA)\n\nNa linha com o seu nome, faça a sua autoavaliação [FELIPE TRINTIM]  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    Qual nível de TRANSPARÊNCIA cada membro teve na sprint anterior? (LEIA A RUBRICA, POIS ISSO NÃO É SIMPLESMENTE UMA NOTA)\n\nNa linha com o seu nome, faça a sua autoavaliação [THOMAS CHABRO]  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    Qual nível de TRANSPARÊNCIA cada membro teve na sprint anterior? (LEIA A RUBRICA, POIS ISSO NÃO É SIMPLESMENTE UMA NOTA)\n\nNa linha com o seu nome, faça a sua autoavaliação [RAFAEL COCA LEVENTHAL]  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    Qual nível de TRANSPARÊNCIA cada membro teve na sprint anterior? (LEIA A RUBRICA, POIS ISSO NÃO É SIMPLESMENTE UMA NOTA)\n\nNa linha com o seu nome, faça a sua autoavaliação [CAIO DE CAMARGO ARANHA TIERI]  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    Qual nível de TRANSPARÊNCIA cada membro teve na sprint anterior? (LEIA A RUBRICA, POIS ISSO NÃO É SIMPLESMENTE UMA NOTA)\n\nNa linha com o seu nome, faça a sua autoavaliação [FELIPE TRINTIM]
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
# [5 rows x 119 columns]

# %%
df.set_index('Selecione o seu Nome', inplace=True)
# df.drop(['Timestamp'], axis=1, inplace=True)

# %%
df.drop(['Timestamp'], axis=1, inplace=True)

# %%
columns = df.columns

# %%
new_columns = {}
for column in columns:
    # posição das palavras 'PRODUTIVIDADE', 'PROATIVIDADE', 'TRANSPARÊNCIA' no nome da coluna
    categoria = column.split()[3]
    nome = column.split('[')[-1].replace(']','')
    #removendo texto desnecessário da coluna e renomeando no padrão ex: PRODUTIVIDADE - NOME DO ALUN@
    new_columns[column] = f'{categoria} - {nome}'

# %%
df.rename(columns=new_columns, inplace=True)

# %%
alunos = list(df.index)
#Dicionário para armazenar as médias para criar um novo dataframe
data = {
    'nome':[],
    'media_produtividade':[],
    'media_proatividade':[],
    'media_transparência':[],
    'auto_produtividade':[],
    'auto_proatividade':[],
    'auto_transparência':[],
    'media':[]
}

# %%
columns_ = df.columns

# %%
columns_sem_aluno = [column for column in columns if 'ALBERTO MANSUR' not in column]

# %%
columns_sem_aluno[0]
# Out:
# 'Qual nível de PRODUTIVIDADE cada membro teve na sprint anterior? (LEIA A RUBRICA, POIS ISSO NÃO É SIMPLESMENTE UMA NOTA)\n\nNa linha com o seu nome, faça a sua autoavaliação [ANDRÉ CORRÊA SANTOS]'

# %%
df.columns
# Out:
# Index(['PRODUTIVIDADE - ANDRÉ CORRÊA SANTOS',
#        'PRODUTIVIDADE - PEDRO PAULO MORENO CAMARGO',
#        'PRODUTIVIDADE - RAFAEL MELHADO ARAUJO LIMA',
#        'PRODUTIVIDADE - ANDRÉ BARBOZA BRAGA DE MELO',
#        'PROATIVIDADE - ANDRÉ CORRÊA SANTOS',
#        'PROATIVIDADE - PEDRO PAULO MORENO CAMARGO',
#        'PROATIVIDADE - RAFAEL MELHADO ARAUJO LIMA',
#        'PROATIVIDADE - ANDRÉ BARBOZA BRAGA DE MELO',
#        'TRANSPARÊNCIA - ANDRÉ CORRÊA SANTOS',
#        'TRANSPARÊNCIA - PEDRO PAULO MORENO CAMARGO',
#        ...
#        'PRODUTIVIDADE - CAIO DE CAMARGO ARANHA TIERI',
#        'PRODUTIVIDADE - FELIPE TRINTIM', 'PROATIVIDADE - THOMAS CHABRO',
#        'PROATIVIDADE - RAFAEL COCA LEVENTHAL',
#        'PROATIVIDADE - CAIO DE CAMARGO ARANHA TIERI',
#        'PROATIVIDADE - FELIPE TRINTIM', 'TRANSPARÊNCIA - THOMAS CHABRO',
#        'TRANSPARÊNCIA - RAFAEL COCA LEVENTHAL',
#        'TRANSPARÊNCIA - CAIO DE CAMARGO ARANHA TIERI',
#        'TRANSPARÊNCIA - FELIPE TRINTIM'],
#       dtype='object', length=117)

# %%
categorias = ['PRODUTIVIDADE', 'PROATIVIDADE', 'TRANSPARÊNCIA']
for aluno in alunos:
    if aluno != 'ALBERTO MANSUR':
        data['nome'].append(aluno)
        soma = 0
        for categoria in categorias:
            nome_coluna = f'{categoria} - {aluno}'
            media_colegas = df.loc[(df.index != aluno) ,nome_coluna].dropna().mean()
            soma += media_colegas

            auto_avaliacao = df.loc[(df.index == aluno) ,nome_coluna][0]

            data[f'media_{categoria.lower()}'].append(media_colegas)
            data[f'auto_{categoria.lower()}'].append(auto_avaliacao)
        data['media'].append(soma/3)

# %%
# data

# %%
df_medias = pd.DataFrame(data=data)

# %%
df_medias['dif_produtividade'] = df_medias['media_produtividade'] - df_medias['auto_produtividade']
df_medias['dif_proatividade'] = df_medias['media_proatividade'] - df_medias['auto_proatividade']
df_medias['dif_transparência'] = df_medias['media_transparência'] - df_medias['auto_transparência']

# %%
df_medias.loc[:,['nome','dif_produtividade','dif_proatividade','dif_transparência']]
# Out:
#                                    nome  dif_produtividade  dif_proatividade  \
# 0      FERNANDO GIUSEPPE AVILA BELTRAMO           0.000000          0.000000
# 1              ERIC ANDREI LIMA POSSATO          -0.500000         -0.500000
# 2          GUILHERME DOS SANTOS MARTINS           0.000000          0.333333
# 3            PEDRO PAULO MORENO CAMARGO           0.666667          0.666667
# 4                   ANDRÉ CORRÊA SANTOS           0.666667          0.666667
# 5         ANTÔNIO AMARAL EGYDIO MARTINS           0.666667         -0.333333
# 6               GIOVANA CASSONI ANDRADE           0.000000          0.333333
# 7                          ENZO BOZELLI           0.500000          0.500000
# 8               RODRIGO ANCIÃES PATELLI           0.500000          0.000000
# 9              VINICIUS MATHEUS MORALES           0.000000          0.000000
# 10            VICTOR LUIS GAMA DE ASSIS          -0.666667         -0.666667
# 11      ARTHUR MARTINS DE SOUZA BARRETO          -1.000000         -0.666667
# 12                         LUCAS GURGEL           0.666667          0.666667
# 13         LINCOLN RODRIGO PEREIRA MELO           0.500000          0.000000
# 14    DOM RUAN SUZANO FIGUEIRA DA SILVA           0.000000          0.000000
# 15                      HUDSON MONTEIRO           0.000000          0.000000
# 16          JOÃO GABRIEL VALENTIM ROCHA           0.000000          0.000000
# 17                   MURILO PRADO WEYNE           0.333333          0.666667
# 18                CAIO RIBEIRO DE PAULA           0.000000          0.000000
# 19             ARIEL TAMEZGUI LEVENTHAL          -0.666667         -0.333333
# 20              PEDRO CLIQUET DO AMARAL           0.000000          0.000000
# 21                          ANDRÉ BRITO           0.666667          0.666667
# 22               ARTHUR CISOTTO MACHADO          -0.666667         -0.666667
# 23                 MARLON SILVA PEREIRA           0.666667         -0.333333
# 24                     RAFAEL ELI KATRI           0.000000          0.000000
# 25                   PEDRO BITTAR BARÃO           0.000000          0.000000
# 26         FERNANDA DE OLIVEIRA PEREIRA           0.000000          0.000000
# 27  LEONARDO DA FRANÇA MOURA DE ANDRADE          -0.333333          0.666667
# 28                RAFAEL COCA LEVENTHAL           0.333333          0.666667
# 29                        THOMAS CHABRO           0.666667          0.333333
# 30                       FELIPE TRINTIM          -1.000000         -0.666667
# 31           ARTHUR BOSCHINI DA FONSECA           0.333333          0.666667
# 32                         CAIO TRAVAIN           0.666667         -0.666667
# 33                   JOSEPH KALLAS NETO           0.000000         -0.666667
# 34           RAFAEL MELHADO ARAUJO LIMA          -1.000000         -1.000000
# 35         CAIO DE CAMARGO ARANHA TIERI          -0.666667          0.333333
# 36          ANDRÉ BARBOZA BRAGA DE MELO           1.000000          0.000000
# 37                        ENRICCO GEMHA          -0.500000         -0.500000
#
#     dif_transparência
# 0            0.000000
# 1           -0.500000
# 2            0.333333
# 3            0.333333
# 4            0.333333
# 5            0.666667
# 6            0.333333
# 7            0.500000
# 8            0.500000
# 9            0.000000
# 10          -0.333333
# 11          -1.000000
# 12           1.000000
# 13           0.000000
# 14           0.000000
# 15           0.000000
# 16           0.000000
# 17           0.333333
# 18           0.000000
# 19          -0.666667
# 20           0.000000
# 21          -0.333333
# 22          -0.333333
# 23           0.333333
# 24           0.000000
# 25           0.000000
# 26          -1.000000
# 27           0.666667
# 28           0.666667
# 29           0.666667
# 30          -0.666667
# 31          -0.333333
# 32           0.666667
# 33          -0.666667
# 34          -1.000000
# 35          -0.666667
# 36           0.333333
# 37          -0.500000

# %%
df_medias.to_excel('sprint2_medias.xlsx')
