# %%
import pandas as pd

# %%
df = pd.read_excel('sprint_2_responses.xlsx')
df.set_index('Selecione o seu Nome', inplace=True)
df.drop(['Timestamp'], axis=1, inplace=True)

# %%
columns = df.columns

# %%
new_columns = {}
for column in columns:
    # posição das palavras 'PRODUTIVIDADE', 'PROATIVIDADE', 'TRANSPARÊNCIA' no nome da coluna
    categoria = column.split()[3]
    nome = column.split('[')[-1].replace(']','')
    #removendo texto desnecessário da coluna e renomeando no padrão ex: PRODUTIVIDADE - NOME DO ALUN@
    new_columns[column] = f'{categoria} - {nome}'

# %%
df.rename(columns=new_columns, inplace=True)

# %%
responder = []

# %%
transposed = df.T
for aluno in df.index:

    index_filter = [index for index in transposed.index if 'PRODUTIVIDADE' in index]
    if 5 in list(transposed.loc[index_filter, aluno].dropna()):
        responder.append(aluno)

# %%
responder
# Out:
# []

# %%
#respostas do aluno
aluno = 'ARTHUR MARTINS DE SOUZA BARRETO'
transposed.loc[index_filter, aluno].dropna()
# Out:
# PRODUTIVIDADE - ANTÔNIO AMARAL EGYDIO MARTINS      4.0
# PRODUTIVIDADE - ARTHUR MARTINS DE SOUZA BARRETO    4.0
# PRODUTIVIDADE - ARIEL TAMEZGUI LEVENTHAL           4.0
# PRODUTIVIDADE - MURILO PRADO WEYNE                 4.0
# Name: ARTHUR MARTINS DE SOUZA BARRETO, dtype: float64

# %%
#respostas do aluno
aluno = 'ARTHUR MARTINS DE SOUZA BARRETO'
index_aluno = [linha for linha in transposed.index if aluno in linha] 

transposed.loc[index_aluno,:]
# Out:
# Selecione o seu Nome                             ANDRÉ BRITO  \
# PRODUTIVIDADE - ARTHUR MARTINS DE SOUZA BARRETO          NaN
# PROATIVIDADE - ARTHUR MARTINS DE SOUZA BARRETO           NaN
# TRANSPARÊNCIA - ARTHUR MARTINS DE SOUZA BARRETO          NaN
#
# Selecione o seu Nome                             ANDRÉ CORRÊA SANTOS  \
# PRODUTIVIDADE - ARTHUR MARTINS DE SOUZA BARRETO                  NaN
# PROATIVIDADE - ARTHUR MARTINS DE SOUZA BARRETO                   NaN
# TRANSPARÊNCIA - ARTHUR MARTINS DE SOUZA BARRETO                  NaN
#
# Selecione o seu Nome                             ANTÔNIO AMARAL EGYDIO MARTINS  \
# PRODUTIVIDADE - ARTHUR MARTINS DE SOUZA BARRETO                            3.0
# PROATIVIDADE - ARTHUR MARTINS DE SOUZA BARRETO                             4.0
# TRANSPARÊNCIA - ARTHUR MARTINS DE SOUZA BARRETO                            3.0
#
# Selecione o seu Nome                             ARIEL TAMEZGUI LEVENTHAL  \
# PRODUTIVIDADE - ARTHUR MARTINS DE SOUZA BARRETO                       4.0
# PROATIVIDADE - ARTHUR MARTINS DE SOUZA BARRETO                        4.0
# TRANSPARÊNCIA - ARTHUR MARTINS DE SOUZA BARRETO                       3.0
#
# Selecione o seu Nome                             ARTHUR BOSCHINI DA FONSECA  \
# PRODUTIVIDADE - ARTHUR MARTINS DE SOUZA BARRETO                         NaN
# PROATIVIDADE - ARTHUR MARTINS DE SOUZA BARRETO                          NaN
# TRANSPARÊNCIA - ARTHUR MARTINS DE SOUZA BARRETO                         NaN
#
# Selecione o seu Nome                             ARTHUR CISOTTO MACHADO  \
# PRODUTIVIDADE - ARTHUR MARTINS DE SOUZA BARRETO                     NaN
# PROATIVIDADE - ARTHUR MARTINS DE SOUZA BARRETO                      NaN
# TRANSPARÊNCIA - ARTHUR MARTINS DE SOUZA BARRETO                     NaN
#
# Selecione o seu Nome                             ARTHUR MARTINS DE SOUZA BARRETO  \
# PRODUTIVIDADE - ARTHUR MARTINS DE SOUZA BARRETO                              4.0
# PROATIVIDADE - ARTHUR MARTINS DE SOUZA BARRETO                               4.0
# TRANSPARÊNCIA - ARTHUR MARTINS DE SOUZA BARRETO                              4.0
#
# Selecione o seu Nome                             CAIO DE CAMARGO ARANHA TIERI  \
# PRODUTIVIDADE - ARTHUR MARTINS DE SOUZA BARRETO                           NaN
# PROATIVIDADE - ARTHUR MARTINS DE SOUZA BARRETO                            NaN
# TRANSPARÊNCIA - ARTHUR MARTINS DE SOUZA BARRETO                           NaN
#
# Selecione o seu Nome                             CAIO TRAVAIN  \
# PRODUTIVIDADE - ARTHUR MARTINS DE SOUZA BARRETO           NaN
# PROATIVIDADE - ARTHUR MARTINS DE SOUZA BARRETO            NaN
# TRANSPARÊNCIA - ARTHUR MARTINS DE SOUZA BARRETO           NaN
#
# Selecione o seu Nome                             DOM RUAN SUZANO FIGUEIRA DA SILVA  \
# PRODUTIVIDADE - ARTHUR MARTINS DE SOUZA BARRETO                                NaN
# PROATIVIDADE - ARTHUR MARTINS DE SOUZA BARRETO                                 NaN
# TRANSPARÊNCIA - ARTHUR MARTINS DE SOUZA BARRETO                                NaN
#
# Selecione o seu Nome                             ...  MURILO PRADO WEYNE  \
# PRODUTIVIDADE - ARTHUR MARTINS DE SOUZA BARRETO  ...                 2.0
# PROATIVIDADE - ARTHUR MARTINS DE SOUZA BARRETO   ...                 2.0
# TRANSPARÊNCIA - ARTHUR MARTINS DE SOUZA BARRETO  ...                 2.0
#
# Selecione o seu Nome                             PEDRO BITTAR BARÃO  \
# PRODUTIVIDADE - ARTHUR MARTINS DE SOUZA BARRETO                 NaN
# PROATIVIDADE - ARTHUR MARTINS DE SOUZA BARRETO                  NaN
# TRANSPARÊNCIA - ARTHUR MARTINS DE SOUZA BARRETO                 NaN
#
# Selecione o seu Nome                             PEDRO CLIQUET DO AMARAL  \
# PRODUTIVIDADE - ARTHUR MARTINS DE SOUZA BARRETO                      NaN
# PROATIVIDADE - ARTHUR MARTINS DE SOUZA BARRETO                       NaN
# TRANSPARÊNCIA - ARTHUR MARTINS DE SOUZA BARRETO                      NaN
#
# Selecione o seu Nome                             PEDRO PAULO MORENO CAMARGO  \
# PRODUTIVIDADE - ARTHUR MARTINS DE SOUZA BARRETO                         NaN
# PROATIVIDADE - ARTHUR MARTINS DE SOUZA BARRETO                          NaN
# TRANSPARÊNCIA - ARTHUR MARTINS DE SOUZA BARRETO                         NaN
#
# Selecione o seu Nome                             RAFAEL COCA LEVENTHAL  \
# PRODUTIVIDADE - ARTHUR MARTINS DE SOUZA BARRETO                    NaN
# PROATIVIDADE - ARTHUR MARTINS DE SOUZA BARRETO                     NaN
# TRANSPARÊNCIA - ARTHUR MARTINS DE SOUZA BARRETO                    NaN
#
# Selecione o seu Nome                             RAFAEL MELHADO ARAUJO LIMA  \
# PRODUTIVIDADE - ARTHUR MARTINS DE SOUZA BARRETO                         NaN
# PROATIVIDADE - ARTHUR MARTINS DE SOUZA BARRETO                          NaN
# TRANSPARÊNCIA - ARTHUR MARTINS DE SOUZA BARRETO                         NaN
#
# Selecione o seu Nome                             RODRIGO ANCIÃES PATELLI  \
# PRODUTIVIDADE - ARTHUR MARTINS DE SOUZA BARRETO                      NaN
# PROATIVIDADE - ARTHUR MARTINS DE SOUZA BARRETO                       NaN
# TRANSPARÊNCIA - ARTHUR MARTINS DE SOUZA BARRETO                      NaN
#
# Selecione o seu Nome                             THOMAS CHABRO  \
# PRODUTIVIDADE - ARTHUR MARTINS DE SOUZA BARRETO            NaN
# PROATIVIDADE - ARTHUR MARTINS DE SOUZA BARRETO             NaN
# TRANSPARÊNCIA - ARTHUR MARTINS DE SOUZA BARRETO            NaN
#
# Selecione o seu Nome                             VICTOR LUIS GAMA DE ASSIS  \
# PRODUTIVIDADE - ARTHUR MARTINS DE SOUZA BARRETO                        NaN
# PROATIVIDADE - ARTHUR MARTINS DE SOUZA BARRETO                         NaN
# TRANSPARÊNCIA - ARTHUR MARTINS DE SOUZA BARRETO                        NaN
#
# Selecione o seu Nome                             VINICIUS MATHEUS MORALES
# PRODUTIVIDADE - ARTHUR MARTINS DE SOUZA BARRETO                       NaN
# PROATIVIDADE - ARTHUR MARTINS DE SOUZA BARRETO                        NaN
# TRANSPARÊNCIA - ARTHUR MARTINS DE SOUZA BARRETO                       NaN
#
# [3 rows x 34 columns]

# %%
index_aluno
df.loc[:,index_aluno].dropna()
# Out:
#                                  PRODUTIVIDADE - ARTHUR MARTINS DE SOUZA BARRETO  \
# Selecione o seu Nome
# ANTÔNIO AMARAL EGYDIO MARTINS                                                3.0
# ARIEL TAMEZGUI LEVENTHAL                                                     4.0
# ARTHUR MARTINS DE SOUZA BARRETO                                              4.0
# MURILO PRADO WEYNE                                                           2.0
#
#                                  PROATIVIDADE - ARTHUR MARTINS DE SOUZA BARRETO  \
# Selecione o seu Nome
# ANTÔNIO AMARAL EGYDIO MARTINS                                               4.0
# ARIEL TAMEZGUI LEVENTHAL                                                    4.0
# ARTHUR MARTINS DE SOUZA BARRETO                                             4.0
# MURILO PRADO WEYNE                                                          2.0
#
#                                  TRANSPARÊNCIA - ARTHUR MARTINS DE SOUZA BARRETO
# Selecione o seu Nome
# ANTÔNIO AMARAL EGYDIO MARTINS                                                3.0
# ARIEL TAMEZGUI LEVENTHAL                                                     3.0
# ARTHUR MARTINS DE SOUZA BARRETO                                              4.0
# MURILO PRADO WEYNE                                                           2.0

# %%
#Exemplo: pegando resposta com valor 5 em PRODUTIVIDADE
aluno = 'ANDRÉ BRITO'
5 in list(transposed.loc[index_filter, aluno].dropna())
# Out:
# True
